# %%
import pandas
data = pandas.read_csv("datasets/Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
array=data.values
array
# Out:
# array([[1, 5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [2, 4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [3, 4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4, 4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5, 5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [6, 5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [7, 4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [8, 5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [9, 4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [10, 4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [11, 5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [12, 4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [13, 4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [14, 4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [15, 5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [16, 5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [17, 5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [18, 5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [19, 5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [20, 5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
# ...

# %%
X = array[:,1:5]
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.0, 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.0, 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.0, 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.0, 1.4, 0.1],
#        [4.3, 3.0, 1.1, 0.1],
#        [5.8, 4.0, 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1.0, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5.0, 3.0, 1.6, 0.2],
#        [5.0, 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
Y = array[:,5]

Y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
from sklearn import model_selection
X_train,X_test,Y_train,Y_test = model_selection.train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
#choose a model

from sklearn.svm import SVC
model = SVC()
model.fit(X_train,Y_train)
# Out:
# SVC()

# %%
#model accuracy
predictions = model.predict(X_test)
print("Model predicted", predictions)
print("Expected", Y_test)
# Out:
# Model predicted ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-setosa' 'Iris-setosa']
# Expected ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
# ...

# %%
#accurage in %
from sklearn.metrics import accuracy_score
print("Accuracy",accuracy_score(Y_test,predictions))
# Out:
# Accuracy 1.0

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
model1 =  LogisticRegression()
model1.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
# model accuracy
predictions = model1.predict(X_test)
print("model predicted",predictions)
print("Expected", Y_test)
# Out:
# model predicted ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-setosa' 'Iris-setosa']
# Expected ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
# ...

# %%
#accuracy %

from sklearn.metrics import accuracy_score
print("Accuracy",accuracy_score(Y_test, predictions))
# Out:
# Accuracy 1.0

# %%
from sklearn.naive_bayes import GaussianNB
model2 = GaussianNB()
model2.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
# model accuracy
predictions = model2.predict(X_test)
print("model predicted",predictions)
print("Expected", Y_test)
# Out:
# model predicted ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-setosa' 'Iris-setosa']
# Expected ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
# ...

# %%
#accuracy %

from sklearn.metrics import accuracy_score
print("Accuracy",accuracy_score(Y_test, predictions))
# Out:
# Accuracy 1.0

# %%
#Decision tree
from sklearn.tree import DecisionTreeClassifier
model3 = DecisionTreeClassifier()
model3.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
#model accuracy
predictions = model3.predict(X_test)
print("Model predicted",predictions)
print("Expected", Y_test)
# Out:
# Model predicted ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-setosa' 'Iris-setosa']
# Expected ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
# ...

# %%
#accuracy %

from sklearn.metrics import accuracy_score
print("Accuracy",accuracy_score(Y_test, predictions))
# Out:
# Accuracy 1.0

# %%
# GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier 
model4 = GradientBoostingClassifier()
model4.fit(X_train,Y_train)
# Out:
# GradientBoostingClassifier()

# %%
#Model Accuracy
predictions = model4.predict(X_test)
print("Model predicted", predictions)
print("Expected",Y_test)
# Out:
# Model predicted ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-setosa' 'Iris-setosa']
# Expected ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
# ...

# %%
#ACCURACY %
from sklearn.metrics import accuracy_score
print("Accuracy",accuracy_score(Y_test,predictions))
# Out:
# Accuracy 1.0

# %%
#RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
model5= RandomForestClassifier()

model5.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
#model accuracy
predictions = model5.predict(X_test)
print("Model predicted",predictions)
print("Expected", Y_test)
# Out:
# Model predicted ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-setosa' 'Iris-setosa']
# Expected ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
# ...

# %%
#ACCURACY %
from sklearn.metrics import accuracy_score
print("Accuracy",accuracy_score(Y_test,predictions))
# Out:
# Accuracy 1.0

# %%
# predict
measure = [[5.5,4.7,3.8,2.6]]

outcome1 = model.predict(measure)
print("The species will be", outcome1)

outcome2 = model1.predict(measure)
print("The species will be", outcome2)

outcome3 = model2.predict(measure)
print("The species will be", outcome3)

outcome4 = model3.predict(measure)
print("The species will be", outcome4)

outcome5 = model4.predict(measure)
print("The species will be", outcome4)

outcome6 = model5.predict(measure)
print("The species will be", outcome6)
# Out:
# The species will be ['Iris-versicolor']
# The species will be ['Iris-versicolor']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-versicolor']

# %%
measure1 = [[6.9,5.3,4.2,9.8]]

outcome1 = model.predict(measure1)
print("The species will be", outcome1)

outcome2 = model1.predict(measure1)
print("The species will be", outcome2)

outcome3 = model2.predict(measure1)
print("The species will be", outcome3)

outcome4 = model3.predict(measure1)
print("The species will be", outcome4)

outcome5 = model4.predict(measure1)
print("The species will be", outcome4)

outcome6 = model5.predict(measure1)
print("The species will be", outcome6)
# Out:
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-versicolor']

# %%
measure2 = [[5.6,6.7,8.9,2.3]]

outcome1 = model.predict(measure2)
print("The species will be", outcome1)

outcome2 = model1.predict(measure2)
print("The species will be", outcome2)

outcome3 = model2.predict(measure2)
print("The species will be", outcome3)

outcome4 = model3.predict(measure2)
print("The species will be", outcome4)

outcome5 = model4.predict(measure2)
print("The species will be", outcome4)

outcome6 = model5.predict(measure2)
print("The species will be", outcome6)
# Out:
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']

# %%
measure3 = [[4.9,5.2,4.4,2.6]]

outcome1 = model.predict(measure3)
print("The species will be", outcome1)

outcome2 = model1.predict(measure3)
print("The species will be", outcome2)

outcome3 = model2.predict(measure3)
print("The species will be", outcome3)

outcome4 = model3.predict(measure3)
print("The species will be", outcome4)

outcome5 = model4.predict(measure3)
print("The species will be", outcome4)

outcome6 = model5.predict(measure3)
print("The species will be", outcome6)
# Out:
# The species will be ['Iris-versicolor']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-virginica']
# The species will be ['Iris-versicolor']

# %%
measure4 = [[5.1,3.4,1.5,0.2]]

outcome1 = model.predict(measure)
print("The species will be", outcome1)

outcome2 = model1.predict(measure)
print("The species will be", outcome2)

outcome3 = model2.predict(measure)
print("The species will be", outcome3)

outcome4 = model3.predict(measure)
print("The species will be", outcome4)

outcome5 = model4.predict(measure)
print("The species will be", outcome4)

outcome6 = model5.predict(measure)
print("The species will be", outcome6)
outcome1 = model.predict(measure4)
print("The species will be", outcome1)

outcome2 = model1.predict(measure4)
print("The species will be", outcome2)

outcome3 = model2.predict(measure4)
print("The species will be", outcome3)

outcome4 = model3.predict(measure4)
print("The species will be", outcome4)

outcome5 = model4.predict(measure4)
print("The species will be", outcome4)

outcome6 = model5.predict(measure4)
print("The species will be", outcome6)
# Out:
# The species will be ['Iris-setosa']
# The species will be ['Iris-setosa']
# The species will be ['Iris-setosa']
# The species will be ['Iris-setosa']
# The species will be ['Iris-setosa']
# The species will be ['Iris-setosa']
