# %%
#loading the dataset into a dataframe
import pandas
data = pandas.read_csv("datasets/bank.csv")
data
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    LP001002    Male      No      Graduate            No             5849
# 1    LP001003    Male     Yes      Graduate            No             4583
# 2    LP001005    Male     Yes      Graduate           Yes             3000
# 3    LP001006    Male     Yes  Not Graduate            No             2583
# 4    LP001008    Male      No      Graduate            No             6000
# ..        ...     ...     ...           ...           ...              ...
# 609  LP002978  Female      No      Graduate            No             2900
# 610  LP002979    Male     Yes      Graduate            No             4106
# 611  LP002983    Male     Yes      Graduate            No             8072
# 612  LP002984    Male     Yes      Graduate            No             7583
# 613  LP002990  Female      No      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount Property_Area Loan_Status
# ...

# %%
#printing out a onbe particular column
data["Gender"]
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
data["Self_Employed"]
# Out:
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4       No
#       ...
# 609     No
# 610     No
# 611     No
# 612     No
# 613    Yes
# Name: Self_Employed, Length: 614, dtype: object

# %%
#check whether the dataset contain empty slot
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#we notice that self_emplooyed column contains 32 empty slots.Since thhis column contains categorical data,we need to fill the empty slots with categorical value
data["Self_Employed"].fillna("unknown", inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#showing the first 50 records of the new dataframe
data.head(50)
# Out:
#      Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0   LP001002    Male      No      Graduate            No             5849
# 1   LP001003    Male     Yes      Graduate            No             4583
# 2   LP001005    Male     Yes      Graduate           Yes             3000
# 3   LP001006    Male     Yes  Not Graduate            No             2583
# 4   LP001008    Male      No      Graduate            No             6000
# 5   LP001011    Male     Yes      Graduate           Yes             5417
# 6   LP001013    Male     Yes  Not Graduate            No             2333
# 7   LP001014    Male     Yes      Graduate            No             3036
# 8   LP001018    Male     Yes      Graduate            No             4006
# 9   LP001020    Male     Yes      Graduate            No            12841
# 10  LP001024    Male     Yes      Graduate            No             3200
# 11  LP001027    Male     Yes      Graduate       unknown             2500
# ...

# %%
data["LoanAmount"]
# Out:
# 0        NaN
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
#since the loan amount column contains quantitive data,we shall find the mean of all other entries and replace the empty slots with the mean.
mean_loan = data["LoanAmount"].mean()
mean_loan
# Out:
# 146.41216216216216

# %%
#use the mean to fill the null value
data["LoanAmount"].fillna(mean_loan, inplace=True)

# %%
#confirm whether you have empty slots
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
#we can describe our dataset
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count       614.000000         614.000000  614.000000
# mean       5403.459283        1621.245798  146.412162
# std        6109.041673        2926.248369   84.037468
# min         150.000000           0.000000    9.000000
# 25%        2877.500000           0.000000  100.250000
# 50%        3812.500000        1188.500000  129.000000
# 75%        5795.000000        2297.250000  164.750000
# max       81000.000000       41667.000000  700.000000

# %%
#finding out the number of males to that of females
data.groupby("Gender").size()
# Out:
# Gender
# Female    125
# Male      489
# dtype: int64

# %%
data.groupby("Education").size()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# dtype: int64

# %%
#finding out the number of graduate and not graduate based on their gender
data.groupby(["Gender", "Education"]).size()
# Out:
# Gender  Education
# Female  Graduate        104
#         Not Graduate     21
# Male    Graduate        376
#         Not Graduate    113
# dtype: int64

# %%
data.groupby(["Gender", "Education","Self_Employed"]).size()
# Out:
# Gender  Education     Self_Employed
# Female  Graduate      No                83
#                       Yes               15
#                       unknown            6
#         Not Graduate  No                15
#                       Yes                4
#                       unknown            2
# Male    Graduate      No               306
#                       Yes               50
#                       unknown           20
#         Not Graduate  No                96
#                       Yes               13
#                       unknown            4
# dtype: int64

# %%
data.groupby(["Gender", "Education","Self_Employed", "Married"]).size()
# Out:
# Gender  Education     Self_Employed  Married
# Female  Graduate      No             No          55
#                                      Yes         28
#                       Yes            No           9
#                                      Yes          6
#                       unknown        No           5
#                                      Yes          1
#         Not Graduate  No             No          10
#                                      Yes          5
#                       Yes            No           3
#                                      Yes          1
#                       unknown        No           1
#                                      Yes          1
# Male    Graduate      No             No          81
#                                      Yes        225
#                       Yes            No          12
#                                      Yes         38
#                       unknown        No           6
# ...

# %%
#find the mean of all genders
data.groupby(["Gender", "Married"])["LoanAmount"].mean()
# Out:
# Gender  Married
# Female  No         118.455715
#         Yes        169.724099
# Male    No         136.485083
#         Yes        153.743093
# Name: LoanAmount, dtype: float64

# %%
data.groupby(["Gender", "Married","Property_Area"])["LoanAmount"].mean()
# Out:
# Gender  Married  Property_Area
# Female  No       Rural            124.526316
#                  Semiurban        122.178116
#                  Urban            109.550434
#         Yes      Rural            152.444444
#                  Semiurban        159.456486
#                  Urban            221.250000
# Male    No       Rural            146.463913
#                  Semiurban        131.668458
#                  Urban            131.077059
#         Yes      Rural            159.224867
#                  Semiurban        154.131440
#                  Urban            148.611977
# Name: LoanAmount, dtype: float64

# %%
#checking the datatype of the different columns
data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
#visualizing the different outputs
data.groupby("Gender").size().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
data.groupby(["Gender","Married"]).size().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#check the versions that exists inside of a matplot lib module
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
#specify one of the version
plt.style.use("seaborn-v0_8")

# %%
#A count plot is a univariate bar graph.it means it only allows us to draw a bargraph by passing only one parameter
sns.countplot(x=data["Gender"],palette="autumn")
plt.title("Gender Distribution")
plt.xlabel("Different Gender Categories")
plt.ylabel("Distribution in Numbers")
# Out:
# /tmp/ipykernel_3452/1622597465.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data["Gender"],palette="autumn")
# Text(0, 0.5, 'Distribution in Numbers')

# %%
#creating a barplot.
#A barplot is multivariate i.e it accepts one to draw a bar graph using different columns
#A barplot is drawn by use of a categorical collumn against a quantitative column
import numpy

sns.barplot(x="Gender",y="LoanAmount", data=data, estimator=numpy.mean, palette="Greens", hue="Property_Area")
plt.title("Distribution of Gender against Loan Amount")
# Out:
# Text(0.5, 1.0, 'Distribution of Gender against Loan Amount')

# %%
#Swarmplot: It helps tto visualize where more members of a certain group lies.
sns.swarmplot(x="Gender", y="ApplicantIncome",data=data, palette="winter",hue="Loan_Status")
plt.title("Distribution of Gender against Applicant Income")
# Out:
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Distribution of Gender against Applicant Income')
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 53.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/user/.local/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#scatterplot: It is also used to show the distribution of different entities of a column
sns.scatterplot(x="LoanAmount", y="ApplicantIncome", data=data, palette="magma", hue="Education")
# Out:
# <Axes: xlabel='LoanAmount', ylabel='ApplicantIncome'>
