# %%
import pandas
data = pandas.read_csv("datasets/supermarket.csv")
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
data.groupby("Gender").size()
# Out:
# Gender
# Female    501
# Male      499
# dtype: int64

# %%
data.groupby("Product line").size()
# Out:
# Product line
# Electronic accessories    170
# Fashion accessories       178
# Food and beverages        174
# Health and beauty         152
# Home and lifestyle        160
# Sports and travel         166
# dtype: int64

# %%
data.groupby("Customer type").size()
# Out:
# Customer type
# Member    501
# Normal    499
# dtype: int64

# %%
data.groupby(["Branch", "City", "Customer type", "Product line"]).size()
# Out:
# Branch  City       Customer type  Product line
# A       Yangon     Member         Electronic accessories    31
#                                   Fashion accessories       22
#                                   Food and beverages        29
#                                   Health and beauty         22
#                                   Home and lifestyle        34
#                                   Sports and travel         29
#                    Normal         Electronic accessories    29
#                                   Fashion accessories       29
#                                   Food and beverages        29
#                                   Health and beauty         25
#                                   Home and lifestyle        31
#                                   Sports and travel         30
# B       Mandalay   Member         Electronic accessories    27
#                                   Fashion accessories       32
# ...

# %%
data.groupby(["City", "Payment"])["cogs"].mean()
# Out:
# City       Payment
# Mandalay   Cash           305.969364
#            Credit card    326.298440
#            Ewallet        282.455575
# Naypyitaw  Cash           330.920565
#            Credit card    294.727551
#            Ewallet        333.830943
# Yangon     Cash           292.478364
#            Credit card    303.065481
#            Ewallet        297.236349
# Name: cogs, dtype: float64

# %%
data.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
data.groupby("Gender").size().plot(kind ='pie',autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
data.groupby(["City", "Customer type"]).size().plot(kind = 'pie', autopct = '%1.1f%%')
# Out:
# <Axes: >

# %%
data.groupby(["Branch", "Product line"]).size().plot(kind = 'pie', autopct = '%1.1f%%')
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-v0_8")

# %%
sns.countplot(x=data["City"],palette="spring")
plt.title("Cities with our Customers")
plt.xlabel("Cities")
plt.ylabel("Number of Customers")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1320\1943543262.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data["City"],palette="spring")
# Text(0, 0.5, 'Number of Customers')

# %%
sns.countplot(x=data["Customer type"],palette="summer")
plt.title("Cities with our Customers")
plt.xlabel("Branches")
plt.ylabel("Number of Customers")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1320\1971445808.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data["Customer type"],palette="summer")
# Text(0, 0.5, 'Number of Customers')

# %%
import numpy
import seaborn as sns


sns.barplot(x="City",y="Total", data=data, estimator=numpy.mean, palette="autumn", hue="Customer type")
plt.title("Total number of clients in different cities")
# Out:
# Text(0.5, 1.0, 'Total number of clients in different cities')

# %%
import numpy
import seaborn as sns


sns.barplot(x="Payment",y="Tax 5%", data=data, estimator=numpy.mean, palette="winter", hue="Product line")
plt.title("Tax evaluation of members in regards various product lines.")
# Out:
# Text(0.5, 1.0, 'Tax evaluation of members in regards various product lines.')

# %%
sns.swarmplot(x="Gender", y="cogs",data=data, palette="spring",hue="Customer type")
plt.title("Distribution of Gender against cogs")
# Out:
# Text(0.5, 1.0, 'Distribution of Gender against cogs')

# %%
sns.swarmplot(x="City", y="Rating",data=data, palette="autumn",hue="Branch")
plt.title("A swarmplot showing the rating in different cities")
# Out:
# Text(0.5, 1.0, 'A swarmplot showing the rating in different cities')
